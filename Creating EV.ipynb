# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)

# %%
c_attendance = pd.read_csv("data/Attendance_and_Capacity_Data.csv")
df_attendance.head()
df_attendance['proportion'] = df_attendance.Attendance / df_attendance.Capacity

# %%
plt.hist(df_attendance.proportion, bins=20)
df_attendance[df_attendance['proportion']!= 1].proportion.max()
# Out:
# 1.1371919135973414

# %%
df_DMA = pd.read_csv("data/DMA_Households.csv")
df_DMA[df_DMA['DMA_TV_Households_Millions'].notnull()]
# Out:
#    Team  DMA_TV_Households_Millions
# 0   ATL                        2.41
# 1   BOS                        2.42
# 2   BRK                        7.35
# 3   CHA                        1.19
# 4   CHI                        3.46
# 5   CLE                        1.50
# 6   DAL                        2.71
# 7   DEN                        1.63
# 8   DET                        1.85
# 9   GSW                        2.49
# 10  HOU                        2.45
# 11  IND                        1.09
# 12  LAC                        5.48
# 13  LAL                        5.48
# 14  MEM                        0.63
# 15  MIA                        1.70
# 16  MIL                        0.90
# 17  MIN                        1.74
# 18  NOP                        0.64
# 19  NYK                        7.35
# 20  OKC                        0.72
# 21  ORL                        1.52
# 22  PHI                        2.94
# 23  PHX                        1.89
# 24  POR                        1.14
# ...

# %%
df_wpct = pd.read_csv("data/End_of_Season_WPct.csv")
df_wpct.head()
# Out:
#    Season       ATL       BOS       BRK       CHA       CHI       CLE       DAL       DEN       DET       GSW       HOU       IND       LAC       LAL       MEM       MIA       MIL       MIN       NOP       NYK       OKC       ORL       PHI       PHX       POR       SAC       SAS       TOR       UTA       WAS
# 0    2010  0.536585  0.682927  0.292683  0.414634  0.756098  0.231707  0.695122  0.609756  0.365854  0.439024  0.524390  0.451220  0.390244  0.695122  0.560976  0.707317  0.426829  0.207317  0.560976  0.512195  0.670732  0.634146  0.500000  0.487805  0.585366  0.292683  0.743902  0.268293  0.475610  0.280488
# 1    2011  0.606061  0.590909  0.333333  0.106061  0.757576  0.318182  0.545455  0.575758  0.378788  0.348485  0.515152  0.636364  0.606061  0.621212  0.621212  0.696970  0.469697  0.393939  0.318182  0.545455  0.712121  0.560606  0.530303  0.500000  0.424242  0.333333  0.757576  0.348485  0.545455  0.303030
# ...

# %%
for col in df_wpct.columns[1:]:
    fig1 = plt.figure()
    ax1 = fig1.add_subplot(111)
    plt.plot(df_wpct['Season'],df_wpct[col],'-o')
    plt.xlabel(col)
# Out:
# /Users/William/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
df_ratings = pd.read_csv("data/National_Ratings.csv")
df_ratings.head()
# Out:
#    National_Gm_Num Network        Date Start Time  End Time  Duration Away Team     Home Team  National Rating  Average Viewers (000)  Average Households (000)
# 0                1     TNT  2016-10-25    7:33 PM  10:12 PM       159       NYK     Cleveland              2.2                   2872                      2044
# 1                2     TNT  2016-10-25   10:12 PM  12:56 AM       164       SAS  Golden State              2.6                   3483                      2428
# 2                3    ESPN  2016-10-26    8:04 PM  10:42 PM       158       OKC  Philadelphia              1.4                   1583                      1224
# 3                4    ESPN  2016-10-26   10:42 PM   1:12 AM       150       HOU   L.A. Lakers              1.7                   2002                      1518
# 4                5     TNT  2016-10-27    8:13 PM  10:49 PM       156       BOS       Chicago              1.6                   1961                      1430

# %%
plt.hist(df_ratings['National Rating'], bins=30)
# Out:
# (array([  93.,  180.,   93.,   73.,  113.,  130.,  109.,   35.,   58.,
#           32.,   27.,   18.,   12.,    6.,   13.,    2.,    4.,    4.,
#            0.,    0.,    1.,    1.,    0.,    0.,    0.,    2.,    0.,
#            0.,    0.,    1.]),
#  array([ 0.1       ,  0.28666667,  0.47333333,  0.66      ,  0.84666667,
#          1.03333333,  1.22      ,  1.40666667,  1.59333333,  1.78      ,
#          1.96666667,  2.15333333,  2.34      ,  2.52666667,  2.71333333,
#          2.9       ,  3.08666667,  3.27333333,  3.46      ,  3.64666667,
#          3.83333333,  4.02      ,  4.20666667,  4.39333333,  4.58      ,
#          4.76666667,  4.95333333,  5.14      ,  5.32666667,  5.51333333,
#          5.7       ]),
#  <a list of 30 Patch objects>)

# %%
df_web = pd.read_csv("data/Web_Metrics.csv")
df_web.head()
# Out:
#         Date Team Metric    Value
# 0  2015-10-1  POR    UNQ  16437.0
# 1  2015-10-2  POR    UNQ  24339.0
# 2  2015-10-3  POR    UNQ  28026.0
# 3  2015-10-4  POR    UNQ  20034.0
# 4  2015-10-5  POR    UNQ  28871.0

# %%
df_web_UNQ = df_web[df_web['Value'].notnull()][df_web['Metric'] == 'UNQ']
df_web_TTS = df_web[df_web['Value'].notnull()][df_web['Metric'] == 'TTS']
# Out:
# /Users/William/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# /Users/William/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
plt.hist(np.log(df_web_UNQ['Value']), bins=20)
print(df_web_UNQ['Value'].max())
# Out:
# 715138.0

# %%
plt.hist(np.log(df_web_TTS['Value']), bins=20)
# Out:
# (array([  2.40000000e+01,   3.50000000e+01,   4.80000000e+01,
#           1.27000000e+02,   1.86000000e+02,   5.35000000e+02,
#           1.67300000e+03,   3.65600000e+03,   5.77200000e+03,
#           6.90800000e+03,   7.35200000e+03,   6.51900000e+03,
#           4.99600000e+03,   3.27800000e+03,   1.82200000e+03,
#           8.65000000e+02,   3.11000000e+02,   8.60000000e+01,
#           2.30000000e+01,   4.00000000e+00]),
#  array([  9.65912036,  10.09723447,  10.53534858,  10.97346269,
#          11.4115768 ,  11.84969091,  12.28780502,  12.72591913,
#          13.16403324,  13.60214735,  14.04026145,  14.47837556,
#          14.91648967,  15.35460378,  15.79271789,  16.230832  ,
#          16.66894611,  17.10706022,  17.54517433,  17.98328843,  18.42140254]),
#  <a list of 20 Patch objects>)

# %%
df_web = pd.read_csv("data/RSN_Ratings.csv")
df_web.head()
# Out:
#   GM  DAY        DATE           ET       LOCAL AWAY HOME   AWAY TV    DUR HH RTG  HH SHR  HH IMP  P2+ IMP HOME TV  DUR.1 HH RTG.1 HH SHR.1 HH IMP.1 P2+ IMP.1 NAT TV CN TV
# 0  1  Tue  2016-10-25   8:00:00 PM  8:00:00 PM  NYK  CLE       NaN    NaN    NaN     NaN     NaN      NaN     NaN    NaN      NaN      NaN      NaN       NaN    TNT   NaN
# 1  2  Tue  2016-10-25  10:00:00 PM  7:00:00 PM  UTA  POR   ROOT-RM  150.0   3.13     5.5    29.0      NaN     KGW  150.0      8.6       14       99       142    NaN   NaN
# 2  3  Tue  2016-10-25  10:30:00 PM  7:30:00 PM  SAS  GSW       NaN    NaN    NaN     NaN     NaN      NaN     NaN    NaN      NaN      NaN      NaN       NaN    TNT   NaN
# 3  4  Wed  2016-10-26   7:00:00 PM  7:00:00 PM  MIA  ORL    FS-SUN  165.0    4.8     8.0    81.0    110.0    FSFL  165.0      1.4        2       21        32    NaN   NaN
# ...

# %% [markdown]
# In creating the ex-post entertainment value, we were told to focus on the following:
# \begin{itemize}
# \item Revenue
# \item Public perception, ratings, etc.
# \item Selection of which games are scheduled when, on which channels.
# \end{itemize}
#
# Focusing on the first two, we thought that it would be best to use a combination of the following variables:
# \begin{itemize}
# \item Attendance/Capacity
# \item Ratings
# \item Social media
# \end{itemize}

# %% [markdown]
# Metric is (Nationals Ratings + Regionals Ratings)/Population + Some game stuff + Social media stuff
